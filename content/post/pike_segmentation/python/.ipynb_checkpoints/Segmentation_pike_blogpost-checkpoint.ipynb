# %% [markdown]
# # Semantic segmentation of 'pike' using U-Net

# %% [markdown]
# ## Preprocess image annotations
# Data consists of 60 images with masks created in VIA. Save reduced sized versions of original images and masks for faster processing to foldes with "_small" prefix.

# %%
#import libaries and define paths
import os
import sys
import json
import numpy as np
from skimage.io import imread, imsave
from skimage.transform import resize
from skimage.draw import draw
import matplotlib.pyplot as plt
import albumentations as A
import albumentations.augmentations.functional as F
import cv2
import random
import torch
from albumentations.pytorch import ToTensorV2
from unet_network import UNet

data_dir = '../data/'
image_dir = os.path.join(data_dir, "images_pike")
image_small_dir = os.path.join(data_dir, "images_pike_small")
mask_dir = os.path.join(data_dir, "images_pike_masks")
mask_small_dir = os.path.join(data_dir, "images_pike_masks_small")
via_proj = os.path.join(data_dir, "via_project.json")

img_longest_size = 1024

# %%
#function for reducing high resolution images to have a maximum height or width no longer than max_length
def img_max_length(img, max_length, mode):
    
    heigth, width = img.shape[:2]
    aspect = width/float(heigth)
    
    if (mode == "img"):
        kwargs = {"order": 1, "anti_aliasing": True, "preserve_range": False}
        
    elif (mode == "mask"):
        kwargs = {"order": 0, "anti_aliasing": False, "preserve_range": True}
        
    else:
        return(1)
    
    if (heigth > max_length or width > max_length):
        
        if(aspect<1):
        #landscape orientation - wide image
            res = int(aspect * max_length)
            img_small = resize(img, (max_length, res), **kwargs)

        elif(aspect>1):
        #portrait orientation - tall image
            res = int(max_length/aspect)
            img_small = resize(img, (res, max_length), **kwargs)

        elif(aspect == 1):
            img_small = resize(img, (max_length, max_length), **kwargs)
        
        else:
            return(1)
        
        if (mode == "mask"):
            img_small = img_small.astype("uint8")

        return(img_small)
    
    else:
        return(img)

# %% [markdown]
# ## Load annotations

# %%
#get VIA annotations from json file
annotations = json.load(open(via_proj)) 
annotations = list(annotations['_via_img_metadata'].values())
annotations = [a for a in annotations if a['regions']]

# %% [markdown]
# ## Create masks

# %%
#create masks and write to file in both original and reduced size

for a in annotations:
    polygons = [r['shape_attributes'] for r in a['regions']] 
    image_path = os.path.join(image_dir, a['filename'])
    image = imread(image_path)
    heigth, width = image.shape[:2]
    mask = np.zeros([heigth, width], dtype=np.uint8)
    
    rr, cc = draw.polygon(polygons[0]['all_points_y'], polygons[0]['all_points_x'])
    mask[rr, cc] = 1
    
    mask_name = a['filename'].replace(".jpg", ".png")
    mask_path = os.path.join(mask_dir, mask_name)
    imsave(mask_path, mask)
    
    mask_small_path = os.path.join(mask_small_dir, mask_name)
    mask_small = img_max_length(mask, img_longest_size, mode = "mask")
    imsave(mask_small_path, mask_small)

# %% [markdown]
# ## Create reduced sized versions of high res images

# %%
images_raw = list(sorted(os.listdir(os.path.join(data_dir, "images_pike"))))

for i in images_raw:
    img_path = os.path.join(image_dir, i)
    img = imread(img_path)
    
    img_name = i.replace(".jpg", ".png")
    img_small_path = os.path.join(image_small_dir, img_name)
    img_small = img_max_length(img, img_longest_size, mode = "img")
    imsave(img_small_path, img_small)

# %%
#plot example of image and mask
ex = "14_L_1.png"
img_ex = imread(os.path.join(image_small_dir, ex))
mask_ex = imread(os.path.join(mask_small_dir, ex))

print(img_ex.shape)
print(mask_ex.shape)

fig, (ax1, ax2, ax3) = plt.subplots(3)

ax1.imshow(img_ex)
ax2.imshow(mask_ex)
ax3.imshow(img_ex*np.expand_dims(mask_ex, 2))
# Out:
# (682, 1024, 3)
# (682, 1024)

# %% [markdown]
# ## Create Pytorch dataset

# %%
#define dataset for pytorch
class PikeDataset(torch.utils.data.Dataset):
    def __init__(self, images_directory, masks_directory, mask_filenames, transform=None):
        self.images_directory = images_directory
        self.masks_directory = masks_directory
        self.mask_filenames = mask_filenames
        self.transform = transform

    def __len__(self):
        return len(self.mask_filenames)

    def __getitem__(self, idx):
        mask_filename = self.mask_filenames[idx]
        image = cv2.imread(os.path.join(self.images_directory, mask_filename))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        mask = cv2.imread(os.path.join(self.masks_directory, mask_filename), cv2.IMREAD_UNCHANGED)
        mask = np.expand_dims(mask, 2)
        mask = mask.astype(np.float32)
        
        if self.transform is not None:
            transformed = self.transform(image=image, mask=mask)
            image = transformed["image"]
            mask = transformed["mask"]
            
        return image, mask

# %% [markdown]
# ## Split files for training and validation

# %%
#split files at random into training (50) and validation (10) datasets
mask_filenames = list(sorted(os.listdir(mask_small_dir)))

random.seed(43)
random.shuffle(mask_filenames)

n_val = 10

val_mask_filenames = mask_filenames[:10]
train_mask_filenames = mask_filenames[10:]

train_transform = A.Compose([
    A.Resize(400, 400, always_apply=True),
    A.RandomCrop(height=200, width = 200, p=0.2),
    A.PadIfNeeded(min_height=400, min_width=400, border_mode=cv2.BORDER_CONSTANT, always_apply=True),
    A.VerticalFlip(p=0.2),              
    A.Blur(p=0.2),
    A.RandomRotate90(p=0.2),
    A.ShiftScaleRotate(p=0.2, border_mode=cv2.BORDER_CONSTANT),
    A.RandomBrightnessContrast(p=0.2),
    A.RandomSunFlare(p=0.2, src_radius=200),
    A.RandomShadow(p=0.2),
    A.RandomFog(p=0.2),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    ToTensorV2(transpose_mask=True)
])

train_dataset = PikeDataset(image_small_dir, mask_small_dir, train_mask_filenames, transform=train_transform)

val_transform = A.Compose([
    A.Resize(400, 400, always_apply=True), 
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)), 
    ToTensorV2(transpose_mask=True)
])

val_dataset = PikeDataset(image_small_dir, mask_small_dir, val_mask_filenames, transform=val_transform)

print(len(train_dataset), len(val_dataset))
# Out:
# 50 10

# %% [markdown]
# ## Define loss function

# %%
#dice loss function
class DiceLoss(torch.nn.Module):

    def __init__(self):
        super(DiceLoss, self).__init__()
        self.smooth = 1.0

    def forward(self, y_pred, y_true):
        assert y_pred.size() == y_true.size()
        y_pred = y_pred[:, 0].contiguous().view(-1)
        y_true = y_true[:, 0].contiguous().view(-1)
        intersection = (y_pred * y_true).sum()
        dsc = (2. * intersection + self.smooth) / (y_pred.sum() + y_true.sum() + self.smooth)
        return 1. - dsc

# %% [markdown]
# ## Set up data for training

# %%
#function to return data loaders
def data_loaders(dataset_train, dataset_valid, bs = 5, workers = 5):

    def worker_init(worker_id):
        np.random.seed(42 + worker_id)

    loader_train = torch.utils.data.DataLoader(
        dataset_train,
        batch_size=bs,
        shuffle=True,
        drop_last=True,
        num_workers=workers,
        worker_init_fn=worker_init,
    )
    
    loader_valid = torch.utils.data.DataLoader(
        dataset_valid,
        batch_size=bs,
        drop_last=False,
        shuffle=False,
        num_workers=workers,
        worker_init_fn=worker_init,
    )

    return {"train": loader_train, "valid": loader_valid}

# %%
#define datasets and load network from file
loaders = data_loaders(train_dataset, val_dataset)

dataset_sizes = {x: len(loaders[x]) for x in ['train', 'valid']}

print(dataset_sizes)

device = torch.device("cpu" if not torch.cuda.is_available() else "cuda")

print(device)
print(torch.__version__)

unet = UNet(in_channels=3, out_channels=1, init_features=8) #adjust init_features
unet.to(device)

dsc_loss = DiceLoss()
best_validation_dsc = 1.0

epoch_loss = {"train": [], "valid": []}

lr = 0.001
epochs = 200

optimizer = torch.optim.Adam(unet.parameters(), lr=lr)

best_val_true = []
best_val_pred = []

# %% [markdown]
# ## Run training loop

# %%
import time
import copy

#training loop 
for epoch in range(epochs):
    print('-' * 100)
    since = time.time()
    best_model_wts = copy.deepcopy(unet.state_dict())
    
    for phase in ["train", "valid"]:
        
        if phase == "train":
            unet.train()
        else:
            unet.eval()
            

        epoch_samples = 0
        running_loss = 0
        
        for i, data in enumerate(loaders[phase]):
            x, y_true = data
            x, y_true = x.to(device), y_true.to(device)
            
            epoch_samples += x.size(0)
            
            optimizer.zero_grad()
            
            with torch.set_grad_enabled(phase == "train"):
                y_pred = unet(x)
                loss = dsc_loss(y_pred, y_true)
                running_loss += loss.item()
                    
                if phase == "train":
                    loss.backward()
                    optimizer.step()

        epoch_phase_loss = running_loss/epoch_samples
        epoch_loss[phase].append(epoch_phase_loss)
    
        if phase == "valid" and epoch_phase_loss < best_validation_dsc:
            best_validation_dsc = epoch_phase_loss
            print("Saving best model")
            best_model_wts = copy.deepcopy(unet.state_dict())
            best_val_true = y_true.detach().cpu().numpy()
            best_val_pred = y_pred.detach().cpu().numpy()
        
    time_elapsed = time.time() - since
    print("Epoch {}/{}: Train loss = {:4f} --- Valid loss = {:4f} --- Time: {:.0f}m {:.0f}s".format(epoch + 1, epochs, epoch_loss["train"][epoch], epoch_loss["valid"][epoch], time_elapsed // 60, time_elapsed % 60))

print("Best validation loss: {:4f}".format(best_validation_dsc))
torch.save(best_model_wts, os.path.join(data_dir, "unet.pt"))
# Out:
# ----------------------------------------------------------------------------------------------------
# Saving best model
# Epoch 1/200: Train loss = 0.150877 --- Valid loss = 0.150549 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Saving best model
# Epoch 2/200: Train loss = 0.148125 --- Valid loss = 0.141923 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Saving best model
# Epoch 3/200: Train loss = 0.145131 --- Valid loss = 0.136400 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Saving best model
# Epoch 4/200: Train loss = 0.143591 --- Valid loss = 0.130237 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 5/200: Train loss = 0.141989 --- Valid loss = 0.130861 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Saving best model
# Epoch 6/200: Train loss = 0.139742 --- Valid loss = 0.125982 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 7/200: Train loss = 0.137705 --- Valid loss = 0.128671 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 8/200: Train loss = 0.135568 --- Valid loss = 0.127572 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 9/200: Train loss = 0.134395 --- Valid loss = 0.127166 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Saving best model
# Epoch 10/200: Train loss = 0.133664 --- Valid loss = 0.124064 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Saving best model
# Epoch 11/200: Train loss = 0.128607 --- Valid loss = 0.123307 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Saving best model
# Epoch 12/200: Train loss = 0.128302 --- Valid loss = 0.119448 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 13/200: Train loss = 0.128581 --- Valid loss = 0.121402 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Saving best model
# Epoch 14/200: Train loss = 0.123735 --- Valid loss = 0.117585 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Saving best model
# Epoch 15/200: Train loss = 0.126732 --- Valid loss = 0.116738 --- Time: 0m 3s
# ----------------------------------------------------------------------------------------------------
# Saving best model
# Epoch 16/200: Train loss = 0.122565 --- Valid loss = 0.112287 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Saving best model
# Epoch 17/200: Train loss = 0.118778 --- Valid loss = 0.109332 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Saving best model
# Epoch 18/200: Train loss = 0.121519 --- Valid loss = 0.109091 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 19/200: Train loss = 0.116472 --- Valid loss = 0.110788 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Saving best model
# Epoch
--- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 178/200: Train loss = 0.019819 --- Valid loss = 0.011294 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 179/200: Train loss = 0.020148 --- Valid loss = 0.014950 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 180/200: Train loss = 0.023229 --- Valid loss = 0.010352 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 181/200: Train loss = 0.022340 --- Valid loss = 0.011673 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 182/200: Train loss = 0.024857 --- Valid loss = 0.011178 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 183/200: Train loss = 0.022652 --- Valid loss = 0.015075 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 184/200: Train loss = 0.019533 --- Valid loss = 0.013765 --- Time: 0m 3s
# ----------------------------------------------------------------------------------------------------
# Epoch 185/200: Train loss = 0.018673 --- Valid loss = 0.012553 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 186/200: Train loss = 0.020774 --- Valid loss = 0.014354 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 187/200: Train loss = 0.024244 --- Valid loss = 0.010365 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 188/200: Train loss = 0.023481 --- Valid loss = 0.011811 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Saving best model
# Epoch 189/200: Train loss = 0.021999 --- Valid loss = 0.009275 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 190/200: Train loss = 0.017424 --- Valid loss = 0.009953 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 191/200: Train loss = 0.019630 --- Valid loss = 0.010705 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 192/200: Train loss = 0.017263 --- Valid loss = 0.012748 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 193/200: Train loss = 0.018210 --- Valid loss = 0.010123 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 194/200: Train loss = 0.018966 --- Valid loss = 0.011163 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 195/200: Train loss = 0.017119 --- Valid loss = 0.011234 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 196/200: Train loss = 0.018772 --- Valid loss = 0.010761 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 197/200: Train loss = 0.023053 --- Valid loss = 0.012662 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 198/200: Train loss = 0.018735 --- Valid loss = 0.013534 --- Time: 0m 3s
# ----------------------------------------------------------------------------------------------------
# Epoch 199/200: Train loss = 0.021439 --- Valid loss = 0.012209 --- Time: 0m 2s
# ----------------------------------------------------------------------------------------------------
# Epoch 200/200: Train loss = 0.018969 --- Valid loss = 0.013146 --- Time: 0m 2s
# Best validation loss: 0.009275

# %% [markdown]
# ## Plot training and validation loss

# %%
plt.plot(epoch_loss["train"], label = "Training")
plt.plot(epoch_loss["valid"], label = "Validation")
plt.legend()
plt.show()

# %% [markdown]
# ## Use trained U-Net to predict masks for new images

# %%
#load weights to network
weights_path = data_dir + "unet.pt"
device = "cpu"


unet = UNet(in_channels=3, out_channels=1, init_features=8)
unet.to(device)
unet.load_state_dict(torch.load(weights_path, map_location=device))

# %%
#define augmentations 
inference_transform = A.Compose([
    A.Resize(400, 400, always_apply=True),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)), 
    ToTensorV2()
])

#define function for predictions
def predict(model, img, device):
    
    model.eval()
    
    with torch.no_grad():
        images = img.to(device)
        output = model(images)
        predicted_masks = (output.squeeze() >= 0.5).float().cpu().numpy()
        
    return(predicted_masks)

#define function to load image and output mask
def get_mask(img_path):
    image = cv2.imread(img_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    original_height, original_width = tuple(image.shape[:2])
    
    image_trans = inference_transform(image = image)
    image_trans = image_trans["image"]
    image_trans = image_trans.unsqueeze(0)
    
    image_mask = predict(unet, image_trans, device)
    image_mask = F.resize(image_mask, original_height, original_width, interpolation=cv2.INTER_NEAREST)
        
    return(image_mask)

# %%
#image example
example_path = image_small_dir+"159_R_1.png"
image = cv2.imread(example_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

mask = get_mask(example_path)

masked_img = image*np.expand_dims(mask, 2).astype("uint8")

# %%
#plot the image, mask and multiplied together
fig, (ax1, ax2, ax3) = plt.subplots(3, figsize=(20, 10))

ax1.imshow(image)
ax2.imshow(mask)
ax3.imshow(masked_img)
